# %%
import pandas as pd
import spacy

# Load the spaCy English language model
nlp = spacy.load("en_core_web_sm")

def pos_tagging(text):
    """
    Apply POS tagging to a given text using spaCy and return the tags.
    Args:
    text (str): A string of text that has been cleaned and normalized.

    Returns:
    list: A list of tuples containing the word and its corresponding POS tag.
    """
    # Process the text through spaCy NLP pipeline
    doc = nlp(text)
    # Create a list of tuples for each token and its POS tag
    return [(token.text, token.pos_) for token in doc]

# Load your dataset
df = pd.read_csv('../data/only_cleaned_data.csv')

# Identify columns to apply POS tagging based on a suffix "_clean"
columns_to_tag = [col for col in df.columns if col.endswith('_clean')]

# Apply POS tagging to each relevant column
for column in columns_to_tag:
    df[column + '_pos'] = df[column].apply(lambda x: pos_tagging(str(x)) if pd.notnull(x) else [])

# Save the POS tagged data to a new CSV file
#df.to_csv('../data/pos_tagged_data.csv', index=False)

# Print some examples to verify
print(df[[column + '_pos' for column in columns_to_tag]].head())
# Out:
#                     Area_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 1  [([, X), (', X), (ella, X), (', PUNCT), (], PU...
# 2  [([, X), (', NOUN), (hikkaduwa, ADJ), (', PUNC...
# 3  [([, X), (', PUNCT), (kandy, ADJ), (', PUNCT),...
# 4  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
#
#       Popular Facilities_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (private, ADJ), (', PUNCT...
# 1  [([, X), (', PUNCT), (airport, NOUN), (', PUNC...
# 2  [([, X), (', PUNCT), (outdoor, ADJ), (', PUNCT...
# 3  [([, X), (', PUNCT), (free, ADJ), (', PUNCT), ...
# 4  [([, X), (', PUNCT), (outdoor, ADJ), (', PUNCT...
#
#              Description_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', NUM), (108, NUM), (', NUM), (,, P...
# 1  [([, X), (', NOUN), (3, NUM), (', NUM), (,, PU...
# 2  [([, X), (', NUM), (33, NUM), (', NUM), (,, PU...
# 3  [([, X), (', NUM), (360, NUM), (', NUM), (,, P...
# 4  [([, X), (', PUNCT), (3r, NUM), (', PUNCT), (,...
#
#               Facilities_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', NOUN), (bathroom, NOUN), (', PROP...
# 1  [([, X), (', NOUN), (bathroom, NOUN), (', PROP...
# 2  [([, X), (', NOUN), (bathroom, NOUN), (', PROP...
# 3  [([, X), (', PUNCT), (outdoors, ADJ), (', PUNC...
# 4  [([, X), (', NOUN), (bathroom, NOUN), (', PROP...
#
#             Surroundings_tokens_lemmatized_clean_pos  \
# 0  [([, X), ('s, AUX), (', NUM), (,, PUNCT), (', ...
# 1  [([, X), ('s, AUX), (', NUM), (,, PUNCT), (', ...
# 2  [([, X), ('s, AUX), (', NUM), (,, PUNCT), (', ...
# 3  [([, X), ('s, AUX), (', NUM), (,, PUNCT), (', ...
# 4  [([, X), ('s, AUX), (', NUM), (,, PUNCT), (', ...
#
#        Bathroom Features_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (toilet, ADJ), (', PUNCT)...
# 1  [([, X), (', PUNCT), (toilet, ADJ), (', PUNCT)...
# 2  [([, X), (', PUNCT), (toilet, ADJ), (', PUNCT)...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 4  [([, X), (', PUNCT), (toilet, ADJ), (', PUNCT)...
#
#         Bedroom Features_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', NOUN), (linen, NOUN), (', PROPN),...
# 1  [([, X), (', NOUN), (2, NUM), (', NUM), (,, PU...
# 2  [([, X), (', NOUN), (2, NUM), (', NUM), (,, PU...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 4  [([, X), (', NOUN), (linen, NOUN), (', PROPN),...
#
#                 Outdoors_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (private, ADJ), (', PUNCT...
# 1  [([, X), (', PUNCT), (outdoor, ADJ), (', PUNCT...
# 2  [([, X), (', PUNCT), (picnic, NOUN), (', PUNCT...
# 3  [([, X), (', PUNCT), (outdoor, ADJ), (', PUNCT...
# 4  [([, X), (', PUNCT), (bbq, X), (', PROPN), (,,...
#
#           Room Amenities_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (socket, VERB), (', PUNCT...
# 1  [([, X), (', PUNCT), (socket, VERB), (', PUNCT...
# 2  [([, X), (', PUNCT), (socket, VERB), (', PUNCT...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 4  [([, X), (', PUNCT), (socket, VERB), (', PUNCT...
#
#               Activities_tokens_lemmatized_clean_pos  ...  \
# 0  [([, X), (', NOUN), (3, NUM), (', NUM), (,, PU...  ...
# 1  [([, X), (', X), (bicycle, NOUN), (', PUNCT), ...  ...
# 2  [([, X), (', PUNCT), (cook, VERB), (', PUNCT),...  ...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...  ...
# 4  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...  ...
#
#           Natural beauty_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 1  [([, X), (', PUNCT), (mountainsingle, NOUN), (...
# 2  [([, X), (', NUM), (44, NUM), (', NUM), (,, PU...
# 3  [([, X), (', PUNCT), (mountainsingle, NOUN), (...
# 4  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
#
#   Beaches in the neighbourhood_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (sampalthivu, VERB), (', ...
# 1  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 2  [([, X), (', PUNCT), (seenigama, X), (', PUNCT...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 4  [([, X), (', X), (negombo, NOUN), (', PUNCT), ...
#
#         Public transport_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', VERB), (traintrincomalee, X), (',...
# 1  [([, X), (', NOUN), (2.6, NUM), (', NUM), (,, ...
# 2  [([, X), (', PUNCT), (trainhikkaduwa, NOUN), (...
# 3  [([, X), (', PUNCT), (trainkandy, ADJ), (', PU...
# 4  [([, X), (', NUM), (450, NUM), (', NUM), (,, P...
#
#         Closest airports_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PROPN), (china, PROPN), (', PROPN...
# 1  [([, X), (', PUNCT), (rajapaksa, ADJ), (', PUN...
# 2  [([, X), (', PROPN), (koggala, NOUN), (', PROP...
# 3  [([, X), (', NUM), (74, NUM), (', NUM), (,, PU...
# 4  [([, X), (', PUNCT), (bandaranaike, INTJ), (',...
#
#   Cancellation/Prepayment_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', X), (cancellation, NOUN), (', PUN...
# 1  [([, X), (', X), (cancellation, NOUN), (', PUN...
# 2  [([, X), (', X), (cancellation, NOUN), (', PUN...
# 3  [([, X), (', X), (cancellation, NOUN), (', PUN...
# 4  [([, X), (', X), (cancellation, NOUN), (', PUN...
#
#   Children and Bed Policies_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', NUM), (13, NUM), (', NUM), (,, PU...
# 1  [([, X), (', PUNCT), (old, ADJ), (', PUNCT), (...
# 2  [([, X), (', PUNCT), (child, NOUN), (', PUNCT)...
# 3  [([, X), (', PUNCT), (child, NOUN), (', PUNCT)...
# 4  [([, X), (', PUNCT), (child, NOUN), (', PUNCT)...
#
#          Age Restriction_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', NOUN), (age, NOUN), (', PUNCT), (...
# 1  [([, X), (', NOUN), (age, NOUN), (', PUNCT), (...
# 2  [([, X), (', NOUN), (age, NOUN), (', PUNCT), (...
# 3  [([, X), (', NOUN), (age, NOUN), (', PUNCT), (...
# 4  [([, X), (', NOUN), (age, NOUN), (', PUNCT), (...
#
#                     Pets_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (free, ADJ), (', PUNCT), ...
# 1  [([, X), (', VERB), (pet, ADJ), (', PUNCT), (,...
# 2  [([, X), (', VERB), (pet, ADJ), (', PUNCT), (,...
# 3  [([, X), (', VERB), (pet, ADJ), (', PUNCT), (,...
# 4  [([, X), (', VERB), (pet, ADJ), (', PUNCT), (,...
#
#   Accepted Payment Methods_tokens_lemmatized_clean_pos  \
# 0  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 1  [([, X), (', VERB), (maestro, X), (', PUNCT), ...
# 2  [([, X), (', VERB), (mastercard, ADV), (', PUN...
# 3  [([, X), (', PUNCT), (unknown, ADJ), (', PUNCT...
# 4  [([, X), (', VERB), (mastercard, ADV), (', PUN...
#
#                  Reviews_tokens_lemmatized_clean_pos
# 0  [([, X), (', PUNCT), (nilaveli, NOUN), (', PUN...
# 1                                   [([, X), (], X)]
# 2                                   [([, X), (], X)]
# 3                                   [([, X), (], X)]
# 4  [([, X), (', PUNCT), (awesome, ADJ), (', PUNCT...
#
# [5 rows x 34 columns]

# %%
import pandas as pd
import spacy

# Load the spaCy English language model
nlp = spacy.load("en_core_web_sm")

def pos_tagging(text):
    """
    Apply POS tagging to a given text using spaCy and return the tags.
    This function filters out punctuation, placeholder tokens like 'unknown', and other non-informative tags.
    Args:
    text (str): A string of text that has been cleaned and normalized.

    Returns:
    list: A list of tuples containing the word and its corresponding POS tag, excluding unwanted tokens.
    """
    # Process the text through spaCy NLP pipeline
    doc = nlp(text)
    # Create a list of tuples for each token and its POS tag, applying filters
    return [(token.text, token.pos_) for token in doc if token.pos_ not in ['PUNCT', 'X'] and not token.text in ['unknown', '[', ']']]

# Load your dataset
df = pd.read_csv('../data/only_cleaned_data.csv')

# Identify columns to apply POS tagging based on a suffix "_clean"
columns_to_tag = [col for col in df.columns if col.endswith('_clean')]

# Apply POS tagging to each relevant column
for column in columns_to_tag:
    df[column + '_pos'] = df[column].apply(lambda x: pos_tagging(str(x)) if pd.notnull(x) else [])

# Save the POS tagged data to a new CSV file
df.to_csv('../data/pos_tagged_data.csv', index=False)

# Print some examples to verify
print(df[[column + '_pos' for column in columns_to_tag]].head())
# Out:
#   Area_tokens_lemmatized_clean_pos  \
# 0                               []
# 1                               []
# 2    [(', NOUN), (hikkaduwa, ADJ)]
# 3                   [(kandy, ADJ)]
# 4                               []
#
#       Popular Facilities_tokens_lemmatized_clean_pos  \
# 0  [(private, ADJ), (beach, NOUN), (outdoor, ADJ)...
# 1  [(airport, NOUN), (shuttle, NOUN), (', NOUN), ...
# 2  [(outdoor, ADJ), (swimming, VERB), (pool, NOUN...
# 3  [(free, ADJ), (wifi, NOUN), (family, NOUN), (r...
# 4  [(outdoor, ADJ), (swimming, VERB), (pool, NOUN...
#
#              Description_tokens_lemmatized_clean_pos  \
# 0  [(', NUM), (108, NUM), (', NUM), (108, NUM), (...
# 1  [(', NOUN), (3, NUM), (', NUM), (2.6, NUM), ('...
# 2  [(', NUM), (33, NUM), (', NUM), (1.8, NUM), (k...
# 3  [(', NUM), (360, NUM), (', NUM), (3, NUM), (',...
# 4  [(3r, NUM), (1, NUM), (', NUM), (km, VERB), ('...
#
#               Facilities_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 1  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 2  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 3  [(outdoors, ADJ), (outdoors, ADJ), (food, NOUN...
# 4  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
#
#             Surroundings_tokens_lemmatized_clean_pos  \
# 0  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 1  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 2  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 3  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 4  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
#
#        Bathroom Features_tokens_lemmatized_clean_pos  \
# 0  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 1  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 2  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 3                                                 []
# 4  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
#
#         Bedroom Features_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (linen, NOUN), (', PROPN), (wardro...
# 1  [(', NOUN), (2, NUM), (', NUM), (metre, NOUN),...
# 2  [(', NOUN), (2, NUM), (', NUM), (metre, NOUN),...
# 3                                                 []
# 4  [(', NOUN), (linen, NOUN), (', PROPN), (wardro...
#
#                 Outdoors_tokens_lemmatized_clean_pos  \
# 0  [(private, ADJ), (beach, NOUN), (outdoor, ADJ)...
# 1  [(outdoor, ADJ), (fireplace, NOUN), (picnic, N...
# 2  [(picnic, NOUN), (area, NOUN), (outdoor, ADJ),...
# 3  [(outdoor, ADJ), (furniture, NOUN), (terrace, ...
# 4  [(', PROPN), (facility, NOUN), (additional, AD...
#
#           Room Amenities_tokens_lemmatized_clean_pos  \
# 0  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 1  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 2  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 3                                                 []
# 4         [(socket, VERB), (near, ADJ), (bed, NOUN)]
#
#               Activities_tokens_lemmatized_clean_pos  ...  \
# 0  [(', NOUN), (3, NUM), (', NUM), (km, VERB), ('...  ...
# 1  [(bicycle, NOUN), (rental, ADJ), (additional, ...  ...
# 2  [(cook, VERB), (class, NOUN), (additional, ADJ...  ...
# 3                                                 []  ...
# 4                                                 []  ...
#
#           Natural beauty_tokens_lemmatized_clean_pos  \
# 0                                                 []
# 1  [(mountainsingle, NOUN), (', PROPN), (tree, NO...
# 2  [(', NUM), (44, NUM), (', NUM), (km, VERB), ('...
# 3  [(mountainsingle, NOUN), (', PROPN), (tree, NO...
# 4                                                 []
#
#   Beaches in the neighbourhood_tokens_lemmatized_clean_pos  \
# 0  [(sampalthivu, VERB), (', NOUN), (beach, NOUN)...
# 1                                                 []
# 2  [(beach, NOUN), (1.4, NUM), (', NUM), (km, VER...
# 3                                                 []
# 4  [(negombo, NOUN), (beach, NOUN), (350, NUM), (...
#
#         Public transport_tokens_lemmatized_clean_pos  \
# 0  [(', VERB), (6, NUM), (', NUM), (km, VERB), ('...
# 1  [(', NOUN), (2.6, NUM), (', NUM), (km, VERB), ...
# 2  [(trainhikkaduwa, NOUN), (1.2, NUM), (', NUM),...
# 3  [(trainkandy, ADJ), (railway, NOUN), (station,...
# 4  [(', NUM), (450, NUM), (', NUM), (2.8, NUM), (...
#
#         Closest airports_tokens_lemmatized_clean_pos  \
# 0  [(', PROPN), (china, PROPN), (', PROPN), (bay,...
# 1  [(rajapaksa, ADJ), (international, ADJ), (airp...
# 2  [(', PROPN), (koggala, NOUN), (', PROPN), (air...
# 3  [(', NUM), (74, NUM), (', NUM), (km, VERB), ('...
# 4  [(bandaranaike, INTJ), (international, ADJ), (...
#
#   Cancellation/Prepayment_tokens_lemmatized_clean_pos  \
# 0  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 1  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 2  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 3  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 4  [(cancellation, NOUN), (prepayment, NOUN), (po...
#
#   Children and Bed Policies_tokens_lemmatized_clean_pos  \
# 0  [(', NUM), (13, NUM), (', NUM), (year, NOUN), ...
# 1  [(old, ADJ), (1, NUM), (', NUM), (year, NOUN),...
# 2  [(child, NOUN), (policie, ADJ), (child, NOUN),...
# 3  [(child, NOUN), (policie, ADJ), (child, NOUN),...
# 4  [(child, NOUN), (policie, ADJ), (child, NOUN),...
#
#          Age Restriction_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 1  [(', NOUN), (age, NOUN), (restriction, NOUN), ...
# 2  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 3  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 4  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
#
#                     Pets_tokens_lemmatized_clean_pos  \
# 0  [(free, ADJ), (pet, NOUN), (allow, VERB), (ext...
# 1             [(', VERB), (pet, ADJ), (allow, VERB)]
# 2             [(', VERB), (pet, ADJ), (allow, VERB)]
# 3             [(', VERB), (pet, ADJ), (allow, VERB)]
# 4             [(', VERB), (pet, ADJ), (allow, VERB)]
#
#   Accepted Payment Methods_tokens_lemmatized_clean_pos  \
# 0                                                 []
# 1  [(', VERB), (mastercard, ADV), (', PROPN), (jc...
# 2       [(', VERB), (mastercard, ADV), (visa, NOUN)]
# 3                                                 []
# 4       [(', VERB), (mastercard, ADV), (visa, NOUN)]
#
#                  Reviews_tokens_lemmatized_clean_pos
# 0  [(nilaveli, NOUN), (asia, PROPN), (', PROPN), ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [(awesome, ADJ), (beach, NOUN), (', PROPN), (5...
#
# [5 rows x 34 columns]

# %%
import pandas as pd
import spacy

# Load the spaCy English language model
nlp = spacy.load("en_core_web_sm")

def pos_tagging(text):
    """
    Apply POS tagging to a given text using spaCy and return the tags.
    This function filters out punctuation, placeholder tokens like 'unknown', and other non-informative tags.
    Args:
    text (str): A string of text that has been cleaned and normalized.

    Returns:
    list: A list of tuples containing the word and its corresponding POS tag, excluding unwanted tokens.
    """
    # Process the text through spaCy NLP pipeline
    doc = nlp(text)
    # Create a list of tuples for each token and its POS tag, applying filters
    return [(token.text, token.pos_) for token in doc if token.pos_ not in ['PUNCT', 'X'] and not token.text in ['unknown', '[', ']']]

# Load your dataset
df = pd.read_csv('../data/only_cleaned_data.csv')

# Identify columns to apply POS tagging based on a suffix "_clean"
columns_to_tag = [col for col in df.columns if col.endswith('_clean')]

# Initialize a new DataFrame to store only POS tagged columns
pos_tagged_df = pd.DataFrame()

# Apply POS tagging to each relevant column and store it in the new DataFrame
for column in columns_to_tag:
    # Apply POS tagging
    df[column + '_pos'] = df[column].apply(lambda x: pos_tagging(str(x)) if pd.notnull(x) else [])
    # Copy the POS tagged data to the new DataFrame
    pos_tagged_df[column + '_pos'] = df[column + '_pos']

# Optionally, include any identifiers or relevant metadata from the original data
if 'id' in df.columns:
    pos_tagged_df['id'] = df['id']  # Assuming 'id' is an identifier column in the original data

# Save the original POS tagged data to a new CSV file
df.to_csv('../data/pos_tagged_data.csv', index=False)

# Save the POS-only tagged data to a separate CSV file
pos_tagged_df.to_csv('../data/pos_only_tagged_data.csv', index=False)

# Print some examples to verify
print(pos_tagged_df.head())
# Out:
#   Area_tokens_lemmatized_clean_pos  \
# 0                               []
# 1                               []
# 2    [(', NOUN), (hikkaduwa, ADJ)]
# 3                   [(kandy, ADJ)]
# 4                               []
#
#       Popular Facilities_tokens_lemmatized_clean_pos  \
# 0  [(private, ADJ), (beach, NOUN), (outdoor, ADJ)...
# 1  [(airport, NOUN), (shuttle, NOUN), (', NOUN), ...
# 2  [(outdoor, ADJ), (swimming, VERB), (pool, NOUN...
# 3  [(free, ADJ), (wifi, NOUN), (family, NOUN), (r...
# 4  [(outdoor, ADJ), (swimming, VERB), (pool, NOUN...
#
#              Description_tokens_lemmatized_clean_pos  \
# 0  [(', NUM), (108, NUM), (', NUM), (108, NUM), (...
# 1  [(', NOUN), (3, NUM), (', NUM), (2.6, NUM), ('...
# 2  [(', NUM), (33, NUM), (', NUM), (1.8, NUM), (k...
# 3  [(', NUM), (360, NUM), (', NUM), (3, NUM), (',...
# 4  [(3r, NUM), (1, NUM), (', NUM), (km, VERB), ('...
#
#               Facilities_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 1  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 2  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
# 3  [(outdoors, ADJ), (outdoors, ADJ), (food, NOUN...
# 4  [(', NOUN), (bathroom, NOUN), (', PROPN), (bat...
#
#             Surroundings_tokens_lemmatized_clean_pos  \
# 0  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 1  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 2  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 3  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
# 4  [('s, AUX), (', NUM), (nearby, ADJ), (restaura...
#
#        Bathroom Features_tokens_lemmatized_clean_pos  \
# 0  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 1  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 2  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
# 3                                                 []
# 4  [(toilet, ADJ), (paper, NOUN), (towel, VERB), ...
#
#         Bedroom Features_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (linen, NOUN), (', PROPN), (wardro...
# 1  [(', NOUN), (2, NUM), (', NUM), (metre, NOUN),...
# 2  [(', NOUN), (2, NUM), (', NUM), (metre, NOUN),...
# 3                                                 []
# 4  [(', NOUN), (linen, NOUN), (', PROPN), (wardro...
#
#                 Outdoors_tokens_lemmatized_clean_pos  \
# 0  [(private, ADJ), (beach, NOUN), (outdoor, ADJ)...
# 1  [(outdoor, ADJ), (fireplace, NOUN), (picnic, N...
# 2  [(picnic, NOUN), (area, NOUN), (outdoor, ADJ),...
# 3  [(outdoor, ADJ), (furniture, NOUN), (terrace, ...
# 4  [(', PROPN), (facility, NOUN), (additional, AD...
#
#           Room Amenities_tokens_lemmatized_clean_pos  \
# 0  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 1  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 2  [(socket, VERB), (near, ADJ), (bed, NOUN), (dr...
# 3                                                 []
# 4         [(socket, VERB), (near, ADJ), (bed, NOUN)]
#
#               Activities_tokens_lemmatized_clean_pos  ...  \
# 0  [(', NOUN), (3, NUM), (', NUM), (km, VERB), ('...  ...
# 1  [(bicycle, NOUN), (rental, ADJ), (additional, ...  ...
# 2  [(cook, VERB), (class, NOUN), (additional, ADJ...  ...
# 3                                                 []  ...
# 4                                                 []  ...
#
#           Natural beauty_tokens_lemmatized_clean_pos  \
# 0                                                 []
# 1  [(mountainsingle, NOUN), (', PROPN), (tree, NO...
# 2  [(', NUM), (44, NUM), (', NUM), (km, VERB), ('...
# 3  [(mountainsingle, NOUN), (', PROPN), (tree, NO...
# 4                                                 []
#
#   Beaches in the neighbourhood_tokens_lemmatized_clean_pos  \
# 0  [(sampalthivu, VERB), (', NOUN), (beach, NOUN)...
# 1                                                 []
# 2  [(beach, NOUN), (1.4, NUM), (', NUM), (km, VER...
# 3                                                 []
# 4  [(negombo, NOUN), (beach, NOUN), (350, NUM), (...
#
#         Public transport_tokens_lemmatized_clean_pos  \
# 0  [(', VERB), (6, NUM), (', NUM), (km, VERB), ('...
# 1  [(', NOUN), (2.6, NUM), (', NUM), (km, VERB), ...
# 2  [(trainhikkaduwa, NOUN), (1.2, NUM), (', NUM),...
# 3  [(trainkandy, ADJ), (railway, NOUN), (station,...
# 4  [(', NUM), (450, NUM), (', NUM), (2.8, NUM), (...
#
#         Closest airports_tokens_lemmatized_clean_pos  \
# 0  [(', PROPN), (china, PROPN), (', PROPN), (bay,...
# 1  [(rajapaksa, ADJ), (international, ADJ), (airp...
# 2  [(', PROPN), (koggala, NOUN), (', PROPN), (air...
# 3  [(', NUM), (74, NUM), (', NUM), (km, VERB), ('...
# 4  [(bandaranaike, INTJ), (international, ADJ), (...
#
#   Cancellation/Prepayment_tokens_lemmatized_clean_pos  \
# 0  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 1  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 2  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 3  [(cancellation, NOUN), (prepayment, NOUN), (po...
# 4  [(cancellation, NOUN), (prepayment, NOUN), (po...
#
#   Children and Bed Policies_tokens_lemmatized_clean_pos  \
# 0  [(', NUM), (13, NUM), (', NUM), (year, NOUN), ...
# 1  [(old, ADJ), (1, NUM), (', NUM), (year, NOUN),...
# 2  [(child, NOUN), (policie, ADJ), (child, NOUN),...
# 3  [(child, NOUN), (policie, ADJ), (child, NOUN),...
# 4  [(child, NOUN), (policie, ADJ), (child, NOUN),...
#
#          Age Restriction_tokens_lemmatized_clean_pos  \
# 0  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 1  [(', NOUN), (age, NOUN), (restriction, NOUN), ...
# 2  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 3  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
# 4  [(', NOUN), (age, NOUN), (requirement, NOUN), ...
#
#                     Pets_tokens_lemmatized_clean_pos  \
# 0  [(free, ADJ), (pet, NOUN), (allow, VERB), (ext...
# 1             [(', VERB), (pet, ADJ), (allow, VERB)]
# 2             [(', VERB), (pet, ADJ), (allow, VERB)]
# 3             [(', VERB), (pet, ADJ), (allow, VERB)]
# 4             [(', VERB), (pet, ADJ), (allow, VERB)]
#
#   Accepted Payment Methods_tokens_lemmatized_clean_pos  \
# 0                                                 []
# 1  [(', VERB), (mastercard, ADV), (', PROPN), (jc...
# 2       [(', VERB), (mastercard, ADV), (visa, NOUN)]
# 3                                                 []
# 4       [(', VERB), (mastercard, ADV), (visa, NOUN)]
#
#                  Reviews_tokens_lemmatized_clean_pos
# 0  [(nilaveli, NOUN), (asia, PROPN), (', PROPN), ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [(awesome, ADJ), (beach, NOUN), (', PROPN), (5...
#
# [5 rows x 34 columns]

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('../data/pos_only_tagged_data.csv')  # Adjust the file path to your dataset

# Specify the column name you want to display
column_name = 'Popular Facilities_tokens_lemmatized_clean_pos'  # Change this to the actual column name

# Check if the column exists in the DataFrame
if column_name in df.columns:
    # Print all data in the specified column
   # Print the count of non-null rows in the specified column
    print(f"Count of non-null rows in '{column_name}': {df[column_name].sum()}")
else:
    print(f"Column '{column_name}' not found in the dataset.")
# Out:
# Count of non-null rows in 'Popular Facilities_tokens_lemmatized_clean_pos': [('private', 'ADJ'), ('beach', 'NOUN'), ('outdoor', 'ADJ'), ('swimming', 'VERB'), ('pool', 'NOUN'), ('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('facility', 'NOUN'), ('disabled', 'ADJ'), ('guest', 'NOUN'), ('beachfront', 'VERB'), ("'", 'PROPN'), ('area', 'NOUN'), ('breakfast', 'NOUN')][('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('restaurant', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN'), ('bar', 'NOUN'), ('breakfast', 'NOUN')][('outdoor', 'ADJ'), ('swimming', 'VERB'), ('pool', 'NOUN'), ('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('restaurant', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN'), ('bar', 'NOUN'), ('breakfast', 'NOUN')][('free', 'ADJ'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('restaurant', 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('facility', 'NOUN'), ('disabled', 'ADJ'), ('guest', 'NOUN'), ('air', 'NOUN'), ('conditioning', 'VERB'), ('terrace', 'NOUN'), ('breakfast', 'NOUN')][('outdoor', 'ADJ'), ('swimming', 'VERB'), ('pool', 'NOUN'), ('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('restaurant', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN'), ('breakfast', 'NOUN')][('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('restaurant', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN'), ('breakfast', 'NOUN')][('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('restaurant', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN'), ('breakfast', 'NOUN')][('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN'), ('restaurant', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('breakfast', 'NOUN')][('free', 'ADJ'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('teacoffee', 'NOUN'), ('maker', 'NOUN'), ('room', 'NOUN')][('free', 'ADJ'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('airport', 'NOUN'), ('shuttle', 'NOUN'), ("'", 'NOUN'), ('non', 'NOUN'), ("'", 'VERB'), ('smoking', 'VERB'), ('room', 'NOUN'), ('room', 'NOUN'), ('service', 'NOUN'), ('breakfast', 'NOUN')][('room', 'NOUN'), ('service', 'NOUN'), ('free', 'ADJ'), ('parking', 'NOUN'), ('wifi', 'NOUN'), ('family', 'NOUN'), ('room', 'NOUN'), ('breakfast', 'NOUN')][("'", 'NUM'), ('24', 'NUM'), ("'", 'NUM'), ('hour', 'NOUN'), ('free', 'ADJ'), ('wifi', 'NOUN') ...
